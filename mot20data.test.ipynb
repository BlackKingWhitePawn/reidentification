# %%
import pandas as pd

# %%
DET_COLUMNS = ['frame', 'id', 'bb_left', 'bb_top',
               'bb_width', 'bb_height', 'is_consider', 'x', 'y', 'z']
DET_TYPES = {
    'frame': int,
    'id': int,
    'bb_left': int,
    'bb_top': int,
    'bb_width': int,
    'bb_height': int,
    'is_consider': int,
    'x': int,
    'y': int,
    'z': int
}

# %% [markdown]
# Судя по тому, как мало объектов в 7м столбце содержат 1, это НЕ флаг, является ли объект пешеходом. на картинках отчетливо видно, что это все пешеходы. **видимо это флаг, который указывает, стоит ли этот объект распознавать как пешехода для сабмита**

# %% [markdown]
# а еще нам не нужно резать тест, на то он и тест

# %%
annotations = pd.read_csv(
    '/home/nick/reidentification/data/MOT20/test/MOT20-07/det/det.txt', names=DET_COLUMNS)
annotations
# Out:
#        frame  id  bb_left  bb_top  bb_width  bb_height  is_consider  x  y  z
# 0          1  -1     1136     679       120        288            1 -1 -1 -1
# 1          1  -1      951     670       123        293            1 -1 -1 -1
# 2          1  -1     1458     414        85        245            0 -1 -1 -1
# 3          1  -1     1267     477       100        248            0 -1 -1 -1
# 4          1  -1     1634     678       134        296            0 -1 -1 -1
# ...      ...  ..      ...     ...       ...        ...          ... .. .. ..
# 20325    585  -1     1211     292        74        157            0 -1 -1 -1
# 20326    585  -1     1216     725       151        312            0 -1 -1 -1
# 20327    585  -1     1377     452       100        214            0 -1 -1 -1
# 20328    585  -1      815     440        84        241            0 -1 -1 -1
# 20329    585  -1      919     280        68        193            0 -1 -1 -1
#
# [20330 rows x 10 columns]

# %%
annotations = pd.read_csv(
    '/home/nick/reidentification/data/MOT20/test/MOT20-04/det/det.txt', names=DET_COLUMNS)
annotations
# Out:
#         frame  id  bb_left  bb_top  bb_width  bb_height  is_consider  x  y  z
# 0           1  -1        1     860        55        206            0 -1 -1 -1
# 1           1  -1     1439     227        88        179            0 -1 -1 -1
# 2           1  -1      925     615        87        202            0 -1 -1 -1
# 3           1  -1      887     848        99        213            0 -1 -1 -1
# 4           1  -1      173     791       105        230            0 -1 -1 -1
# ...       ...  ..      ...     ...       ...        ...          ... .. .. ..
# 228293   2080  -1     1265     155        58        147            0 -1 -1 -1
# 228294   2080  -1      835       4        61        117            0 -1 -1 -1
# 228295   2080  -1      759     551        62        166            0 -1 -1 -1
# 228296   2080  -1      350     717        67        176            0 -1 -1 -1
# 228297   2080  -1      108     143        56        142            0 -1 -1 -1
#
# [228298 rows x 10 columns]

# %%
annotations[annotations['is_consider'] == 1]
# Out:
#         frame  id  bb_left  bb_top  bb_width  bb_height  is_consider  x  y  z
# 196         3  -1      177     788       100        232            1 -1 -1 -1
# 291         4  -1      177     785        99        230            1 -1 -1 -1
# 391         5  -1      177     784        99        230            1 -1 -1 -1
# 492         6  -1      182     783        96        228            1 -1 -1 -1
# 597         7  -1      180     780        99        231            1 -1 -1 -1
# ...       ...  ..      ...     ...       ...        ...          ... .. .. ..
# 226702   2067  -1     1154     784        82        196            1 -1 -1 -1
# 227164   2071  -1     1161     781        80        197            1 -1 -1 -1
# 227280   2072  -1     1165     781        78        195            1 -1 -1 -1
# 227619   2075  -1        1     746        24        230            1 -1 -1 -1
# 228189   2080  -1      390     814        92        207            1 -1 -1 -1
#
# [1683 rows x 10 columns]

# %%
annotations = pd.read_csv(
    '/home/nick/reidentification/data/MOT20/test/MOT20-06/det/det.txt', names=DET_COLUMNS)
annotations
# Out:
#        frame  id  bb_left  bb_top  bb_width  bb_height  is_consider  x  y  z
# 0          1  -1      833     325        97        262            0 -1 -1 -1
# 1          1  -1      612     350        88        212            0 -1 -1 -1
# 2          1  -1     1659     548       109        185            0 -1 -1 -1
# 3          1  -1     1698     198        96        190            0 -1 -1 -1
# 4          1  -1     1461     497       112        236            0 -1 -1 -1
# ...      ...  ..      ...     ...       ...        ...          ... .. .. ..
# 69462   1008  -1      432       2        45         85            0 -1 -1 -1
# 69463   1008  -1      687      63        57        167            0 -1 -1 -1
# 69464   1008  -1     1331     208        58        123            0 -1 -1 -1
# 69465   1008  -1     1283      24        46         96            0 -1 -1 -1
# 69466   1008  -1      382     232        74        153            0 -1 -1 -1
#
# [69467 rows x 10 columns]

# %%
annotations = pd.read_csv(
    '/home/nick/reidentification/data/MOT20/test/MOT20-08/det/det.txt', names=DET_COLUMNS)
annotations
# Out:
#        frame  id  bb_left  bb_top  bb_width  bb_height  is_consider  x  y  z
# 0          1  -1      705     215        90        230            1 -1 -1 -1
# 1          1  -1      935     260        76        207            0 -1 -1 -1
# 2          1  -1      986     221        81        224            0 -1 -1 -1
# 3          1  -1     1850      67        66        162            0 -1 -1 -1
# 4          1  -1     1717     314        69        150            0 -1 -1 -1
# ...      ...  ..      ...     ...       ...        ...          ... .. .. ..
# 43698    806  -1      208      67        48        129            0 -1 -1 -1
# 43699    806  -1        3     673        31         60            0 -1 -1 -1
# 43700    806  -1      864       4        45        108            0 -1 -1 -1
# 43701    806  -1      445     105        57        140            0 -1 -1 -1
# 43702    806  -1      602      58        53        134            0 -1 -1 -1
#
# [43703 rows x 10 columns]

# %% [markdown]
# Тут небольшое противоречие. В этой ссылке указано, что колонок 10. их действительно 10, но ссылка про МОТ15
# - https://arxiv.org/pdf/1504.01942.pdf
# _is_consider score: Indicates how confident the detector is that this instance is a pedestrian. For the ground truth and
# results, it acts as a flag whether the entry is to be considered_
#
# здесь про мот20, но написано, что колонок 9, хотя их 10 и последние 3 полностью заполнены -1, значит это координаты, которые не доступны
# - https://arxiv.org/pdf/2003.09003.pdf
# _DET: Indicates how confident the detector is that this instance is a pedestrian.
# GT: It acts as a flag whether the entry is to be considered (1) or ignored (0)._

# %%
annotations[annotations['is_consider'] == 1]
# Out:
#        frame  id  bb_left  bb_top  bb_width  bb_height  is_consider  x  y  z
# 0          1  -1      705     215        90        230            1 -1 -1 -1
# 56         2  -1      707     215        91        233            1 -1 -1 -1
# 108        3  -1      710     217        91        231            1 -1 -1 -1
# 159        4  -1      713     220        92        233            1 -1 -1 -1
# 216        5  -1      717     222        89        235            1 -1 -1 -1
# ...      ...  ..      ...     ...       ...        ...          ... .. .. ..
# 42891    793  -1      199     612       113        121            1 -1 -1 -1
# 43132    797  -1      807     226        85        219            1 -1 -1 -1
# 43189    798  -1      808     228        85        221            1 -1 -1 -1
# 43306    800  -1     1468     497        91        222            1 -1 -1 -1
# 43307    800  -1      814     229        82        222            1 -1 -1 -1
#
# [285 rows x 10 columns]

# %% [markdown]
# В этом наборе данных нам недоступны координаты в реальном мире

# %%
annotations['x'].unique(), annotations['y'].unique(), annotations['z'].unique()
# Out:
# (array([-1]), array([-1]), array([-1]))

# %% [markdown]
# В трейне для детекций такой же формат данных как и в тесте

# %%
annotations = pd.read_csv(
    '/home/nick/reidentification/data/MOT20/train/MOT20-01/det/det.txt', names=DET_COLUMNS)
annotations
# Out:
#        frame  id  bb_left  bb_top  bb_width  bb_height  is_consider  x  y  z
# 0          1  -1      757     692        96        209            1 -1 -1 -1
# 1          1  -1      667     682       100        222            1 -1 -1 -1
# 2          1  -1      343     818       127        258            1 -1 -1 -1
# 3          1  -1      806     524        71        172            1 -1 -1 -1
# 4          1  -1      196     814       141        265            1 -1 -1 -1
# ...      ...  ..      ...     ...       ...        ...          ... .. .. ..
# 12605    429  -1      942     510        51        125            0 -1 -1 -1
# 12606    429  -1     1258     575        62        160            0 -1 -1 -1
# 12607    429  -1     1381     671        74        203            0 -1 -1 -1
# 12608    429  -1      812     505        43        117            0 -1 -1 -1
# 12609    429  -1     1117     567        54        123            0 -1 -1 -1
#
# [12610 rows x 10 columns]

# %%
annotations[annotations['is_consider'] == 1]
# Out:
#        frame  id  bb_left  bb_top  bb_width  bb_height  is_consider  x  y  z
# 0          1  -1      757     692        96        209            1 -1 -1 -1
# 1          1  -1      667     682       100        222            1 -1 -1 -1
# 2          1  -1      343     818       127        258            1 -1 -1 -1
# 3          1  -1      806     524        71        172            1 -1 -1 -1
# 4          1  -1      196     814       141        265            1 -1 -1 -1
# ...      ...  ..      ...     ...       ...        ...          ... .. .. ..
# 12584    429  -1      529     695        85        225            1 -1 -1 -1
# 12585    429  -1     1110     444        51        122            1 -1 -1 -1
# 12586    429  -1      900     587        73        178            1 -1 -1 -1
# 12587    429  -1     1088     649        85        219            1 -1 -1 -1
# 12588    429  -1     1510     662       104        218            1 -1 -1 -1
#
# [4367 rows x 10 columns]

# %%
annotations['x'].unique(), annotations['y'].unique(), annotations['z'].unique()
# Out:
# (array([-1]), array([-1]), array([-1]))

# %% [markdown]
# Посмотрим на ground truth. Очевидно, он есть только в трейне

# %% [markdown]
# _GT: Visibility ratio, a number between 0 and 1 that says how much of that object is visible. Can be due
# to occlusion and due to image border cropping_

# %%
GT_COLUMNS = ['frame', 'id', 'bb_left', 'bb_top',
              'bb_width', 'bb_height', 'is_consider', 'class', 'visibility']
GT_TYPES = {
    'frame': int,
    'id': int,
    'bb_left': int,
    'bb_top': int,
    'bb_width': int,
    'bb_height': int,
    'is_consider': int,
    'class': int,
    'visibility': float 
}

# %%
annotations = pd.read_csv(
    '/home/nick/reidentification/data/MOT20/train/MOT20-01/gt/gt.txt', names=GT_COLUMNS, dtype=GT_TYPES)
annotations
# Out:
#        frame  id  bb_left  bb_top  bb_width  bb_height  is_consider  class  \
# 0          1   1      199     813       140        268            1      1
# 1          2   1      201     812       140        268            1      1
# 2          3   1      203     812       140        268            1      1
# 3          4   1      206     812       140        268            1      1
# 4          5   1      208     812       140        268            1      1
# ...      ...  ..      ...     ...       ...        ...          ...    ...
# 26642    425  90        4       1       500        813            0     11
# 26643    426  90        4       1       501        812            0     11
# 26644    427  90        4       1       502        812            0     11
# 26645    428  90        4       1       503        811            0     11
# 26646    429  90        4       1       505        811            0     11
#
#        visibility
# 0         0.83643
# 1         0.84015
# ...

# %%
annotations[annotations['is_consider'] == 1]
# Out:
#        frame  id  bb_left  bb_top  bb_width  bb_height  is_consider  class  \
# 0          1   1      199     813       140        268            1      1
# 1          2   1      201     812       140        268            1      1
# 2          3   1      203     812       140        268            1      1
# 3          4   1      206     812       140        268            1      1
# 4          5   1      208     812       140        268            1      1
# ...      ...  ..      ...     ...       ...        ...          ...    ...
# 21581    425  78     1488     432        52         89            1      1
# 21582    426  78     1489     432        52         89            1      1
# 21583    427  78     1489     432        52         89            1      1
# 21584    428  78     1490     432        52         89            1      1
# 21585    429  78     1491     433        52         89            1      1
#
#        visibility
# 0        0.836430
# 1        0.840150
# ...

# %%
annotations = pd.read_csv(
    '/home/nick/reidentification/data/MOT20/train/MOT20-02/gt/gt.txt', names=GT_COLUMNS)
annotations
# Out:
#         frame   id  bb_left  bb_top  bb_width  bb_height  is_consider  class  \
# 0         722    1      547     252        68        145            1      1
# 1         723    1      548     252        68        145            1      1
# 2         724    1      550     252        68        145            1      1
# 3         725    1      552     252        68        145            1      1
# 4         726    1      554     252        68        145            1      1
# ...       ...  ...      ...     ...       ...        ...          ...    ...
# 202210   2778  296        2       1       326        594            0     11
# 202211   2779  296        2       1       332        595            0     11
# 202212   2780  296        2       1       339        597            0     11
# 202213   2781  296        2       1       346        598            0     11
# 202214   2782  296        2       1       353        600            0     11
#
#         visibility
# 0         0.092317
# ...

# %%
annotations[annotations['is_consider'] == 1]
# Out:
#         frame   id  bb_left  bb_top  bb_width  bb_height  is_consider  class  \
# 0         722    1      547     252        68        145            1      1
# 1         723    1      548     252        68        145            1      1
# 2         724    1      550     252        68        145            1      1
# 3         725    1      552     252        68        145            1      1
# 4         726    1      554     252        68        145            1      1
# ...       ...  ...      ...     ...       ...        ...          ...    ...
# 199428   1000  295     1778     484       113        211            1      1
# 199429   1001  295     1785     484       112        211            1      1
# 199430   1002  295     1792     483       110        211            1      1
# 199431   1003  295     1799     483       109        211            1      1
# 199432   1004  295     1806     483       107        211            1      1
#
#         visibility
# 0         0.092317
# ...

# %%
annotations[annotations['class'] == 1]
# Out:
#         frame   id  bb_left  bb_top  bb_width  bb_height  confidence  class  \
# 0         722    1      547     252        68        145           1      1
# 1         723    1      548     252        68        145           1      1
# 2         724    1      550     252        68        145           1      1
# 3         725    1      552     252        68        145           1      1
# 4         726    1      554     252        68        145           1      1
# ...       ...  ...      ...     ...       ...        ...         ...    ...
# 199428   1000  295     1778     484       113        211           1      1
# 199429   1001  295     1785     484       112        211           1      1
# 199430   1002  295     1792     483       110        211           1      1
# 199431   1003  295     1799     483       109        211           1      1
# 199432   1004  295     1806     483       107        211           1      1
#
#         visibility
# 0         0.092317
# ...

# %%
annotations['confidence'].unique()
# Out:
# array([1, 0])

# %%
annotations['class'].unique()
# Out:
# array([ 1,  7, 11])

# %%
annotations['visibility'].unique()
# Out:
# array([0.83643, 0.84015, 0.83704, ..., 0.80867, 0.8055 , 0.79767])

# %%
len(annotations['visibility'])
# Out:
# 26647

# %%
pedestrians = annotations[(annotations['class'] == 1) | (annotations['class'] == 7)]
# pedestrians = annotations[(annotations['class'] == 1)]
pedestrians
# Out:
#         frame   id  bb_left  bb_top  bb_width  bb_height  confidence  class  \
# 0         722    1      547     252        68        145           1      1
# 1         723    1      548     252        68        145           1      1
# 2         724    1      550     252        68        145           1      1
# 3         725    1      552     252        68        145           1      1
# 4         726    1      554     252        68        145           1      1
# ...       ...  ...      ...     ...       ...        ...         ...    ...
# 199428   1000  295     1778     484       113        211           1      1
# 199429   1001  295     1785     484       112        211           1      1
# 199430   1002  295     1792     483       110        211           1      1
# 199431   1003  295     1799     483       109        211           1      1
# 199432   1004  295     1806     483       107        211           1      1
#
#         visibility
# 0         0.092317
# ...

# %%
annotations['frame'].unique()
# Out:
# array([ 722,  723,  724, ..., 2780, 2781, 2782])

# %%
for frame in pedestrians['frame'].unique():
    frame_data = pedestrians[pedestrians['frame'] == frame]
# Out:
# [  1   7  15  55  82 162 171 175 176 177 178 182 183 243 244 245 246 247
#  248 249 250 251 252 253 254 255 256 257 258 259 260 261 262 263 264 265
#  268 269 270 271 272 273 274 275 276 277 278 279 280 281 295]
# [  1   7  15  55  82 162 171 175 176 177 178 182 183 243 244 245 246 247
#  248 249 250 251 252 253 254 255 256 257 258 259 260 261 262 263 264 265
#  268 269 270 271 272 273 274 275 276 277 278 279 280 281 295]
# [  1   7  15  55  82 162 171 175 176 177 178 182 183 243 244 245 246 247
#  248 249 250 251 252 253 254 255 256 257 258 259 260 261 262 263 264 265
#  268 269 270 271 272 273 274 275 276 277 278 279 280 281 295]
# [  1   7  15  55  82 162 171 175 176 177 178 182 183 243 244 245 246 247
#  248 249 250 251 252 253 254 255 256 257 258 259 260 261 262 263 264 265
#  268 269 270 271 272 273 274 275 276 277 278 279 280 281 295]
# [  1   7  15  55  82 162 171 175 176 177 178 182 183 243 244 245 246 247
# ...
